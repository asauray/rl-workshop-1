# %%
import keras
import gym
import numpy as np
import requests

def send_score(reward):
    my_id = 'rl_user_1'
    name = 'My Name goes Here'
    image = 'image_url'
    try:
        requests.post("http://workshop.sauray.com/score", data={'id': my_id, 'name': name, 'score': reward, 'image': image})
    except:
        pass

NUMBER_OF_OBSERVATIONS=8
NUMBER_OF_ACTIONS=4
NUMBER_OF_GAMES_TO_PLAY=400
NUMBER_OF_STEPS=40000
MAX_MEMORY_LENGTH = 100000
NUMBER_INITIAL_OBSERVATIONS = 0
TRAIN_EVERY_N_GAMES=50
TRAIN = True

# One hot encoding array https://fr.wikipedia.org/wiki/Encodage_one-hot
possible_actions = np.arange(0,NUMBER_OF_ACTIONS)
actions_one_hot_encoding = np.zeros((NUMBER_OF_ACTIONS,NUMBER_OF_ACTIONS))
actions_one_hot_encoding[np.arange(NUMBER_OF_ACTIONS),possible_actions] = 1

# Create enviroment
env = gym.make('LunarLander-v2')
env.reset()
# Out:
# Using TensorFlow backend.
# [2018-01-17 15:49:38,032] Making new env: LunarLander-v2
# array([  4.87327576e-04,   9.33382231e-01,   4.93397683e-02,
#         -4.82074579e-01,  -5.57845982e-04,  -1.11762159e-02,
#          0.00000000e+00,   0.00000000e+00])

# %%
from sklearn.linear_model import LinearRegression
from sklearn.externals import joblib

# TODO
# Define the function which returns the model, i.e the function approximator
# You can find information here https://keras.io/models/sequential/
def model():
    return LinearRegression()

def load_model(m, filename='model.pkl'):
    return joblib.load(filename) 

def save_model(m, filename='model.pkl'):
    joblib.dump(m, filename) 

# TODO
# The probability under which a random action is performed
# Try to find the balance between exploration and exploitation
def get_epsilon(game_no, game_max_no):
    return 0.5

# The epsilon greedy policy
# This function should return an action (0, 1, 2 or 3)
# It should call the get_epsilon function
# Under an epsilon probability, pick a random action
# Otherwise, find the best action according to your model
# You should predict the value of the vectors
# [observation1, observation2, ... , action0] [observation1, observation2, ... , action1] etc up to the number of actions (4)
def epsilon_greedy(env, observation, approximator, game):
    return env.action_space.sample()

# %%
#Initialize Memory Array data array 
memoryX = np.zeros(shape=(1,NUMBER_OF_OBSERVATIONS+NUMBER_OF_ACTIONS))
memoryY = np.zeros(shape=(1,1))

try:
    approximator = load_model()
except:
    print("load failed")
    approximator = model()

def calculate_q_values(rewards, b_discount):
    rewards_length = len(rewards)
    for i in range(0, rewards_length):
        if i==0:
            rewards[(rewards_length-1)-i] = (rewards[(rewards_length-1)-i])
        elif i==1:
            rewards[(rewards_length-1)-i] = (rewards[(rewards_length-1)-i]+b_discount*rewards[(rewards_length-1)-i+1])
        else:
            b0 = rewards[(rewards_length-1)-i]
            b1 = b_discount*rewards[(rewards_length-1)-i+1]
            rewards[(rewards_length-1)-i] = (b0+b1)
    return rewards

def update_memory(memoryX, memoryY, X, y):
    if memoryX.shape[0] == 1:
        memoryX = X
        memoryY = y
    else:
        #Add experience to memory
        memoryX = np.concatenate((memoryX, X),axis=0)
        memoryY = np.concatenate((memoryY, y),axis=0)
        # if memory is full remove first element
        if np.alen(memoryX) >= MAX_MEMORY_LENGTH:
            for l in range(np.alen(X)):
                memoryX = np.delete(memoryX, 0, axis=0)
                memoryY = np.delete(memoryY, 0, axis=0)
    return memoryX, memoryY

game_won = 0
game_lost = 0
for game in range(NUMBER_OF_GAMES_TO_PLAY):
    # the vector that combines the environment and the action
    X = np.zeros(shape=(1,NUMBER_OF_OBSERVATIONS+NUMBER_OF_ACTIONS))
    y = np.zeros(shape=(1,1))
    # reset the environment to start a new game
    qs = env.reset()
    sum_rewards = 0
    for step in range (NUMBER_OF_STEPS):

        action = epsilon_greedy(env, qs, approximator, game)
        env.render()
        qs_a = np.concatenate((qs, actions_one_hot_encoding[action]), axis=0)        
        observation,reward,done,info = env.step(action)
        sum_rewards = sum_rewards + reward
        if step == 0:
            X[0] = qs_a
            y = np.array([reward])
            memoryX[0] = qs_a
            memoryY[0] = np.array([reward])
        X = np.vstack((X,qs_a))
        y = np.vstack((y, np.array([reward])))
        
        if done:
            # calculate Q values from end to start, using the Bellman equation
            # You need to find a good parameter for b_discount (look for the Bellman equation)
            calculate_q_values(y, b_discount=0.98)
            (memoryX, memoryY) = update_memory(memoryX, memoryY, X, y)
        
        # Update the states
        qs=observation
        # Train every X game after num_initial_observation
        if done:
            if TRAIN and game >= NUMBER_INITIAL_OBSERVATIONS and game%TRAIN_EVERY_N_GAMES == 0 and game >= TRAIN_EVERY_N_GAMES:
                print("Training  game# ", game,"memory size", memoryX.shape[0])
                approximator.fit(memoryX,memoryY)
                np.save('memoryX.csv', memoryX)
                np.save('memoryY.csv', memoryY)
                save_model(approximator)
                env.reset()
            send_score(sum_rewards)
            if reward >= 0 and reward <99:
                print("Game ",game," ended with positive reward ")
            if reward > 50:
                game_won = game_won + 1
                print("Game ", game," WON *** with reward "+str(reward) )
            else:
                game_lost = game_lost + 1
                print("Game ", game," FAILED *** with reward "+str(reward))
            win_ratio = game_won/(game_won+game_lost)
            print("Success: " + str(win_ratio*100) +"%")
            break
# Out:
# load failed
# Game  0  FAILED *** with reward -100
# Success: 0.0%
# Game  1  FAILED *** with reward -100
# Success: 0.0%
# Game  2  FAILED *** with reward -100
# Success: 0.0%
# Game  3  FAILED *** with reward -100
# Success: 0.0%
# Game  4  FAILED *** with reward -100
# Success: 0.0%
# Game  5  FAILED *** with reward -100
# Success: 0.0%
# Game  6  FAILED *** with reward -100
# Success: 0.0%
# Game  7  FAILED *** with reward -100
# Success: 0.0%
# Game  8  FAILED *** with reward -100
# Success: 0.0%
# Game  9  FAILED *** with reward -100
# Success: 0.0%
# Game  10  FAILED *** with reward -100
# Success: 0.0%
# Game  11  FAILED *** with reward -100
# Success: 0.0%
# Game  12  FAILED *** with reward -100
# Success: 0.0%
# Game  13  FAILED *** with reward -100
# Success: 0.0%
# Game  14  FAILED *** with reward -100
# Success: 0.0%
# Game  15  FAILED *** with reward -100
# Success: 0.0%
# Game  16  FAILED *** with reward -100
# Success: 0.0%
# Game  17  FAILED *** with reward -100
# Success: 0.0%
# Game  18  FAILED *** with reward -100
# Success: 0.0%
# Game  19  FAILED *** with reward -100
# Success: 0.0%
# Game  20  FAILED *** with reward -100
# Success: 0.0%
# Game  21  FAILED *** with reward -100
# Success: 0.0%
# Game  22  FAILED *** with reward -100
# Success: 0.0%
# Game  23  FAILED *** with reward -100
# Success: 0.0%
# Game  80  FAILED *** with reward -100
# Success: 0.0%
# Game  81  FAILED *** with reward -100
# Success: 0.0%
# Game  82  FAILED *** with reward -100
# Success: 0.0%
# Game  83  FAILED *** with reward -100
# Success: 0.0%
# Game  84  FAILED *** with reward -100
# Success: 0.0%
# Game  85  FAILED *** with reward -100
# Success: 0.0%
# Game  86  FAILED *** with reward -100
# Success: 0.0%
# Game  87  FAILED *** with reward -100
# Success: 0.0%
# Game  88  FAILED *** with reward -100
# Success: 0.0%
# Game  89  FAILED *** with reward -100
# Success: 0.0%
# Game  90  FAILED *** with reward -100
# Success: 0.0%
# Game  91  FAILED *** with reward -100
# Success: 0.0%
# Game  92  FAILED *** with reward -100
# Success: 0.0%
# Game  93  FAILED *** with reward -100
# Success: 0.0%
# Game  94  FAILED *** with reward -100
# Success: 0.0%
# Game  95  FAILED *** with reward -100
# Success: 0.0%
# Game  96  FAILED *** with reward -100
# Success: 0.0%
# Game  97  FAILED *** with reward -100
# Success: 0.0%
# Game  98  FAILED *** with reward -100
# Success: 0.0%
# Game  99  FAILED *** with reward -100
# Success: 0.0%
# Training  game#  100 memory size 9475
# Game  100  FAILED *** with reward -100
# Success: 0.0%
# Game  101  FAILED *** with reward -100
# Success: 0.0%
# Game  102  FAILED *** with reward -100
# Success: 0.0%
# Game  103  FAILED *** with reward -100
# Success: 0.0%
# Game  104  FAILED *** with reward -100
# Success: 0.0%
# Game  105  FAILED *** with reward -100
# Success: 0.0%
# Game  106  FAILED *** with reward -100
# Success: 0.0%
# Game  107  FAILED *** with reward -100
# Success: 0.0%
# Game  108  FAILED *** with reward -100
# Success: 0.0%
# Game  109  FAILED *** with reward -100
# Success: 0.0%
# Game  110  FAILED *** with reward -100
# Success: 0.0%
# Game  111  FAILED *** with reward -100
# Success: 0.0%
# Game  112  FAILED *** with reward -100
# Success: 0.0%
# Game  113  FAILED *** with reward -100
# Success: 0.0%
# Game  114  FAILED *** with reward -100
# Success: 0.0%
# Game  115  FAILED *** with reward -100
# Success: 0.0%
# Game  116  FAILED *** with reward -100
# Success: 0.0%
# Game  117  FAILED *** with reward -100
# Success: 0.0%
# Game  118  FAILED *** with reward -100
# Success: 0.0%
# Game  119  FAILED *** with reward -100
# Success: 0.0%
# Game  120  FAILED *** with reward -100
# Success: 0.0%
# Game  121  FAILED *** with reward -100
# Success: 0.0%
# Game  122  FAILED *** with reward -100
# Success: 0.0%
# Game  123  FAILED *** with reward -100
# Success: 0.0%
# Game  124  FAILED *** with reward -100
# Success: 0.0%
# Game  125  FAILED *** with reward -100
# Success: 0.0%
# Game  126  FAILED *** with reward -100
# Success: 0.0%
# Game  127  FAILED *** with reward -100
# Success: 0.0%
# Game  128  FAILED *** with reward -100
# Success: 0.0%
# Game  129  FAILED *** with reward -100
# Success: 0.0%
# Game  130  FAILED *** with reward -100
# Success: 0.0%
# Game  131  FAILED *** with reward -100
# Success: 0.0%
# Game  132  FAILED *** with reward -100
# Success: 0.0%
# Game  133  FAILED *** with reward -100
# Success: 0.0%
# Game  134  FAILED *** with reward -100
# Success: 0.0%
# Game  135  FAILED *** with reward -100
# Success: 0.0%
# Success: 0.0%
# Game  193  FAILED *** with reward -100
# Success: 0.0%
# Game  194  FAILED *** with reward -100
# Success: 0.0%
# Game  195  FAILED *** with reward -100
# Success: 0.0%
# Game  196  FAILED *** with reward -100
# Success: 0.0%
# Game  197  FAILED *** with reward -100
# Success: 0.0%
# Game  198  FAILED *** with reward -100
# Success: 0.0%
# Game  199  FAILED *** with reward -100
# Success: 0.0%
# Training  game#  200 memory size 18777
# Game  200  FAILED *** with reward -100
# Success: 0.0%
# Game  201  FAILED *** with reward -100
# Success: 0.0%
# Game  202  FAILED *** with reward -100
# Success: 0.0%
# Game  203  FAILED *** with reward -100
# Success: 0.0%
# Game  204  FAILED *** with reward -100
# Success: 0.0%
# Game  205  FAILED *** with reward -100
# Success: 0.0%
# Game  206  FAILED *** with reward -100
# Success: 0.0%
# Game  207  FAILED *** with reward -100
# Success: 0.0%
# Game  208  FAILED *** with reward -100
# Success: 0.0%
# Game  209  FAILED *** with reward -100
# Success: 0.0%
# Game  210  FAILED *** with reward -100
# Success: 0.0%
# Game  211  FAILED *** with reward -100
# Success: 0.0%
# Game  212  FAILED *** with reward -100
# Success: 0.0%
# Game  213  FAILED *** with reward -100
# Success: 0.0%
# Game  214  FAILED *** with reward -100
# Success: 0.0%
# Game  215  FAILED *** with reward -100
# Success: 0.0%
# Game  216  FAILED *** with reward -100
# Success: 0.0%
# Game  217  FAILED *** with reward -100
# Success: 0.0%
# Game  218  FAILED *** with reward -100
# Success: 0.0%
# Game  219  FAILED *** with reward -100
# Success: 0.0%
# Game  220  FAILED *** with reward -100
# Success: 0.0%
# Game  221  FAILED *** with reward -100
# Success: 0.0%
# Game  222  FAILED *** with reward -100
# Success: 0.0%
# Game  223  FAILED *** with reward -100
# Success: 0.0%
# Game  224  FAILED *** with reward -100
# Success: 0.0%
# Game  225  FAILED *** with reward -100
# Success: 0.0%
# Game  226  FAILED *** with reward -100
# Success: 0.0%
# Game  227  FAILED *** with reward -100
# Success: 0.0%
# Game  228  FAILED *** with reward -100
# Success: 0.0%
# Game  229  FAILED *** with reward -100
# Success: 0.0%
# Game  230  FAILED *** with reward -100
# Success: 0.0%
# Game  231  FAILED *** with reward -100
# Success: 0.0%
# Game  232  FAILED *** with reward -100
# Success: 0.0%
# Game  233  FAILED *** with reward -100
# Success: 0.0%
# Game  234  FAILED *** with reward -100
# Success: 0.0%
# Game  235  FAILED *** with reward -100
# Success: 0.0%
# Game  236  FAILED *** with reward -100
# Success: 0.0%
# Game  237  FAILED *** with reward -100
# Success: 0.0%
# Game  238  FAILED *** with reward -100
# Success: 0.0%
# Game  239  FAILED *** with reward -100
# Success: 0.0%
# Game  240  FAILED *** with reward -100
# Success: 0.0%
# Game  241  FAILED *** with reward -100
# Success: 0.0%
# Game  242  FAILED *** with reward -100
# Success: 0.0%
# Game  243  FAILED *** with reward -100
# Success: 0.0%
# Game  244  FAILED *** with reward -100
# Success: 0.0%
# Game  245  FAILED *** with reward -100
# Success: 0.0%
# Game  246  FAILED *** with reward -100
# Success: 0.0%
# Game  247  FAILED *** with reward -100
# Success: 0.0%
# Game  248  FAILED *** with reward -100
# Success: 0.0%
# Game  249  FAILED *** with reward -100
# Success: 0.0%
# Training  game#  250 memory size 23497
# Game  250  FAILED *** with reward -100
# Success: 0.0%
# Game  251  FAILED *** with reward -100
# Success: 0.0%
# Game  252  FAILED *** with reward -100
# Success: 0.0%
# Game  253  FAILED *** with reward -100
# Success: 0.0%
# Game  254  FAILED *** with reward -100
# Success: 0.0%
# Game  255  FAILED *** with reward -100
# Success: 0.0%
# Game  256  FAILED *** with reward -100
# Success: 0.0%
# Game  257  FAILED *** with reward -100
# Success: 0.0%
# Game  258  FAILED *** with reward -100
# Success: 0.0%
# Game  259  FAILED *** with reward -100
# Success: 0.0%
# Game  260  FAILED *** with reward -100
# Success: 0.0%
# Game  261  FAILED *** with reward -100
# Success: 0.0%
# Game  262  FAILED *** with reward -100
# Success: 0.0%
# Game  263  FAILED *** with reward -100
# Success: 0.0%
# Game  264  FAILED *** with reward -100
# Success: 0.0%
# Game  265  FAILED *** with reward -100
# Success: 0.0%
# Game  266  FAILED *** with reward -100
# Success: 0.0%
# Game  267  FAILED *** with reward -100
# Success: 0.0%
# Game  268  FAILED *** with reward -100
# Success: 0.0%
# Game  269  FAILED *** with reward -100
# Success: 0.0%
# Game  270  FAILED *** with reward -100
# Success: 0.0%
# Game  271  FAILED *** with reward -100
# Success: 0.0%
# Game  272  FAILED *** with reward -100
# Success: 0.0%
# Game  273  FAILED *** with reward -100
# Success: 0.0%
# Game  274  FAILED *** with reward -100
# Success: 0.0%
# Game  275  FAILED *** with reward -100
# Success: 0.0%
# Game  276  FAILED *** with reward -100
# Success: 0.0%
# Game  277  FAILED *** with reward -100
# Success: 0.0%
# Game  278  FAILED *** with reward -100
# Success: 0.0%
# Game  279  FAILED *** with reward -100
# Success: 0.0%
# Game  280  FAILED *** with reward -100
# Success: 0.0%
# Game  281  FAILED *** with reward -100
# Success: 0.0%
# Game  282  FAILED *** with reward -100
# Success: 0.0%
# Game  283  FAILED *** with reward -100
# Success: 0.0%
# Game  284  FAILED *** with reward -100
# Success: 0.0%
# Game  285  FAILED *** with reward -100
# Success: 0.0%
# Game  286  FAILED *** with reward -100
# Success: 0.0%
# Game  287  FAILED *** with reward -100
# Success: 0.0%
# Game  288  FAILED *** with reward -100
# Success: 0.0%
# Game  289  FAILED *** with reward -100
# Success: 0.0%
# Game  290  FAILED *** with reward -100
# Success: 0.0%
# Game  291  FAILED *** with reward -100
# Success: 0.0%
# Game  292  FAILED *** with reward -100
# Success: 0.0%
# Game  293  FAILED *** with reward -100
# Success: 0.0%
# Game  294  FAILED *** with reward -100
# Success: 0.0%
# Game  295  FAILED *** with reward -100
# Success: 0.0%
# Game  296  FAILED *** with reward -100
# Success: 0.0%
# Game  297  FAILED *** with reward -100
# Success: 0.0%
# Game  298  FAILED *** with reward -100
# Success: 0.0%
# Game  299  FAILED *** with reward -100
# Success: 0.0%
# Training  game#  300 memory size 28139
# Game  300  FAILED *** with reward -100
# Success: 0.0%
# Game  301  FAILED *** with reward -100
# Success: 0.0%
# Game  302  FAILED *** with reward -100
# Success: 0.0%
# Game  303  FAILED *** with reward -100
# Success: 0.0%
